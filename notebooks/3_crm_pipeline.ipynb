# %%
import sqlite3
import requests
import json
import time
import os
from getpass import getpass
from datetime import datetime

# Secure API Key input with validation
API_KEY = getpass("Enter your GHL API Key: ")
    
# Location ID from GHL 
LOCATION_ID = getpass("Enter your GHL location ID: ")

# Configuration
REQUEST_TIMEOUT = 30  # seconds
DELAY_BETWEEN_REQUESTS = 1  # seconds 
MAX_RETRIES = 3
# Out:
# Enter your GHL API Key:  ········
# Enter your GHL location ID:  ········

# %%
def connect_to_db(db_path='instagram_leads.db'):
    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        return conn, cursor
    except sqlite3.Error as e:
        print(f"Database error: {e}")
        raise

conn, cursor = connect_to_db()

# Add necessary columns if they don't exist
columns_to_add = [
    ("sent_to_crm", "INTEGER DEFAULT 0"),
    ("sent_timestamp", "TIMESTAMP"),
    ("retry_count", "INTEGER DEFAULT 0"),
    ("error_message", "TEXT")
]

for column_name, data_type in columns_to_add:
    try:
        cursor.execute(f"ALTER TABLE profiles ADD COLUMN {column_name} {data_type}")
        conn.commit()
        print(f" '{column_name}' column added.")
    except sqlite3.OperationalError as e:
        if "duplicate column name" in str(e):
            print(f" '{column_name}' already exists.")
        else:
            print(f" Error adding column {column_name}: {e}")

print("Database setup complete.")
# Out:
#  'sent_to_crm' column added.
#  'sent_timestamp' column added.
#  'retry_count' column added.
#  'error_message' column added.
# Database setup complete.

# %%
# Get leads with score >= 20 that haven't been sent to GHL yet
cursor.execute('''
    SELECT 
        username, email, phone, website_link, location, 
        follower_count, lead_score, retry_count
    FROM profiles
    WHERE lead_score >= 20 
    AND (sent_to_crm IS NULL OR sent_to_crm = 0)
    AND (retry_count IS NULL OR retry_count < ?)
    ORDER BY lead_score DESC
''', (MAX_RETRIES,))

leads = cursor.fetchall()
print(f" Found {len(leads)} qualified leads to push to GHL.")

# Optional: Show lead distribution by score
if leads:
    print("\nLead Distribution:")
    cursor.execute('''
        SELECT 
            CASE 
                WHEN lead_score >= 80 THEN 'Excellent (80+)'
                WHEN lead_score >= 60 THEN 'High (60-79)'
                WHEN lead_score >= 40 THEN 'Medium (40-59)'
                ELSE 'Basic (20-39)'
            END as score_range,
            COUNT(*) as count
        FROM profiles
        WHERE username IN ({})
        GROUP BY score_range
        ORDER BY MIN(lead_score) DESC
    '''.format(','.join(['?']*len(leads))), [lead[0] for lead in leads])
    
    for score_range, count in cursor.fetchall():
        print(f"   {score_range}: {count} leads")
# Out:
#  Found 2140 qualified leads to push to GHL.
#
# Lead Distribution:
#    Excellent (80+): 8 leads
#    High (60-79): 106 leads
#    Medium (40-59): 1209 leads
#    Basic (20-39): 817 leads

# %%
# API request headers
headers = {
    "Authorization": f"Bearer {API_KEY}",
    "Content-Type": "application/json",
    "User-Agent": "InstagramLeadScraper/1.0"
}

# Helper function to format phone numbers consistently
def format_phone(phone_number):
    if not phone_number:
        return ""
    
    # Remove all non-digit characters
    digits_only = ''.join(filter(str.isdigit, phone_number))
    
    # Check if this looks like a valid North American number
    if len(digits_only) == 10:
        return f"+1{digits_only}"
    elif len(digits_only) > 10:
        return f"+{digits_only}"
    else:
        return digits_only  # Return as is if we can't determine format

# Test the API connection before proceeding
try:
    test_response = requests.get(
        "https://rest.gohighlevel.com/v1/locations/",
        headers=headers,
        timeout=REQUEST_TIMEOUT
    )
    if test_response.status_code == 200:
        print("API connection successful")
    else:
        print(f"API connection warning: {test_response.status_code} - {test_response.text}")
except Exception as e:
    print(f"API connection error: {e}")
    print("Will attempt to send leads anyway...")
# Out:
# API connection successful

# %%
import re

# Statistics counters
success_count = 0
fail_count = 0
skip_count = 0

# Timestamp for this batch
batch_timestamp = datetime.now().isoformat()

# Display estimated time
total_leads = len(leads)
est_minutes = total_leads / 60  # Roughly 1 second per lead
print(f"Starting processing of {total_leads} leads (estimated time: ~{est_minutes:.1f} minutes)")

# Helper function to create a valid email
def sanitize_email(username):
    # Remove invalid email characters and spaces
    sanitized = re.sub(r'[^\w.-]', '', username)
    # Ensure no consecutive dots
    sanitized = re.sub(r'\.+', '.', sanitized)
    # Ensure doesn't start or end with dot
    sanitized = sanitized.strip('.')
    
    if not sanitized or not re.match(r'^[\w.-]+$', sanitized):
        # If completely invalid, use a generic email
        return "noemail@example.com"
    return f"{sanitized}@noemail.instagram.com"

# Improved phone format function
def format_phone(phone_number):
    if not phone_number:
        return ""
    
    # Remove all non-digit characters
    digits_only = ''.join(filter(str.isdigit, phone_number))
    
    # Handle empty or too short
    if not digits_only or len(digits_only) < 7:
        return ""
    
    # North American format (most common in Canada)
    if len(digits_only) == 10:
        return f"+1{digits_only}"
    # With country code already
    elif len(digits_only) > 10:
        return f"+{digits_only}"
    # Other formats - just return digits
    else:
        return digits_only

# Process each lead
for lead_index, lead in enumerate(leads):
    username, email, phone, website, location, follower_count, lead_score, retry_count = lead
    retry_count = retry_count or 0
    
    # Display progress every 200 leads
    if lead_index % 200 == 0 and lead_index > 0:
        progress_pct = (lead_index / total_leads) * 100
        print(f"Progress: {lead_index}/{total_leads} leads processed ({progress_pct:.1f}%)")
    
    
    # Prepare contact data with improved email and phone handling
    contact_data = {
        "locationId": LOCATION_ID,
        "firstName": username,
        # Properly sanitize email address
        "email": email if email else sanitize_email(username),
        # Only include phone if it's valid
        "phone": format_phone(phone) if phone else "",
        "customField": [
            {"id": "ig_handle", "value": f"https://instagram.com/{username}"},
            {"id": "location", "value": location if location else ""},
            {"id": "website_link", "value": website if website else ""},
            {"id": "has_email", "value": "Yes" if email else "No"},
            {"id": "follower_count", "value": str(follower_count) if follower_count else "0"},
            {"id": "lead_score", "value": str(lead_score) if lead_score else "0"}
        ],
        "tags": ["IG Lead", "Lash Tech"] + 
                (["High Value"] if lead_score >= 60 else []) +
                (["Has Email"] if email else ["No Email"]) +
                (["Has Phone"] if phone else []),
        "source": "Instagram Scraper"
    }

    # Remove phone completely if it caused an error before
    if retry_count > 0 and "phone number" in (error_message or ""):
        contact_data.pop("phone", None)

    # Send to GHL 
    max_attempts = 2
    for attempt in range(max_attempts):
        try:
            response = requests.post(
                "https://rest.gohighlevel.com/v1/contacts/",
                headers=headers,
                data=json.dumps(contact_data),
                timeout=REQUEST_TIMEOUT
            )
            
            if response.status_code == 200:
                print(f" Sent: @{username} (Score: {lead_score})")
                cursor.execute(
                    "UPDATE profiles SET sent_to_crm = 1, sent_timestamp = ?, retry_count = ?, error_message = NULL WHERE username = ?",
                    (batch_timestamp, retry_count, username)
                )
                success_count += 1
                break
            else:
                error_msg = f"HTTP {response.status_code}: {response.text[:100]}"
                print(f" Failed to send {username}: {error_msg}")
                
                # Handle specific error types
                if "phone number" in error_msg and "phone" in contact_data:
                    # Remove phone from payload on phone number errors
                    contact_data.pop("phone", None)
                    print(f" Removed phone number and retrying...")
                    continue
                elif "email" in error_msg and email is None:
                    # Use a completely generic email on email errors
                    contact_data["email"] = "noemail@example.com"
                    print(f" Using generic email and retrying...")
                    continue
                elif response.status_code == 429:  # Rate limit
                    print(f" Rate limited. Waiting 10 seconds...")
                    time.sleep(10)
                elif attempt < max_attempts - 1:  # Not last attempt
                    print(f" Retrying...")
                    time.sleep(2)
                else:  # Last attempt failed
                    cursor.execute(
                        "UPDATE profiles SET retry_count = ?, error_message = ? WHERE username = ?",
                        (retry_count + 1, error_msg, username)
                    )
                    fail_count += 1
        
        except Exception as e:
            print(f" Exception sending {username}: {str(e)[:100]}")
            if attempt < max_attempts - 1:
                print(f" Retrying...")
                time.sleep(2)
            else:
                cursor.execute(
                    "UPDATE profiles SET retry_count = ?, error_message = ? WHERE username = ?",
                    (retry_count + 1, str(e)[:200], username)
                )
                fail_count += 1
                break
    
    # Commit after each lead to save progress
    conn.commit()
    
    # Small delay between requests to avoid overwhelming the API
    time.sleep(DELAY_BETWEEN_REQUESTS)
  
    

# Final summary
print("\n==== Summary ====")
print(f"Total leads processed: {len(leads)}")
print(f"Successfully sent: {success_count}")
print(f"Failed: {fail_count}")
print(f"Skipped: {skip_count}")

# Close the database connection
conn.close()
print("\nProcess complete. Database connection closed.")
# Out:
# Starting processing of 2140 leads (estimated time: ~35.7 minutes)
#  Sent: @venusbeautyca (Score: 90)
#  Sent: @all_buffed_up (Score: 90)
#  Failed to send volumelash.wholesale.factory: HTTP 400: {"statusCode":400,"message":"The string supplied did not seem to be a phone number","traceId":"f6c6a
#  Removed phone number and retrying...
#  Sent: @volumelash.wholesale.factory (Score: 80)
#  Sent: @lovebeauty_sylviawang (Score: 80)
#  Sent: @eli.beauty.lashes (Score: 80)
#  Sent: @trancy_tran1987 (Score: 80)
#  Sent: @starring_lash_brow (Score: 80)
#  Sent: @prepbeautyparlour (Score: 80)
#  Sent: @lashes.wholesale.vendor (Score: 70)
#  Sent: @beauty_by_armina (Score: 70)
#  Sent: @glamourqueenartistry (Score: 70)
#  Sent: @tokyobeauteyyc (Score: 70)
#  Sent: @lash_manufacturer_cora (Score: 70)
#  Sent: @maylashandnailsyyc (Score: 70)
#  Failed to send volumelash.wholesale.vendors: HTTP 400: {"statusCode":400,"message":"The string supplied did not seem to be a phone number","traceId":"f3deb
#  Removed phone number and retrying...
#  Sent: @volumelash.wholesale.vendors (Score: 70)
#  Sent: @amys.clients (Score: 70)
#  Sent: @sophiabeauty_birkenhead (Score: 70)
#  Sent: @mina_vinalashes_wholesale (Score: 70)
#  Sent: @arezoo_beaute (Score: 70)
#  Sent: @studio11beautique (Score: 70)
#  Sent: @lashedbyvalz_ (Score: 70)
#  Sent: @microblading_razi (Score: 70)
#  Sent: @herminksexperience_ (Score: 70)
#  Sent: @citylooksbyvisage (Score: 70)
#  Sent: @firstlash.supplies.factory (Score: 70)
#  Sent: @ellemlashco (Score: 70)
#  Sent: @ariah.artistry (Score: 70)
#  Sent: @lashdashyvr (Score: 70)
#  Sent: @lashes.by.mahroo (Score: 70)
#  Sent: @temptationlashes (Score: 70)
#  Sent: @lucybeauty.studio (Score: 70)
#  Sent: @lashroom.byclaudia (Score: 70)
#  Sent: @harsh_beauty002 (Score: 70)
#  Sent: @hfxfancynails (Score: 70)
#  Sent: @lashesbytha (Score: 70)
#  Sent: @bladeitbabe (Score: 70)
#  Sent: @samira_lash.brow (Score: 70)
#  Sent: @domeek.industry (Score: 70)
#  Sent: @merakibrowbar (Score: 60)
#  Sent: @bossladylashes.official (Score: 60)
#  Sent: @baby_doll_lash_boutique (Score: 60)
#  Sent: @lashedtoronto_ (Score: 60)
#  Sent: @luxury_lashesbrows (Score: 60)
#  Sent: @hair_by_shylo (Score: 60)
#  Sent: @eyecandy.lashandbrow (Score: 60)
#  Sent: @lashin_out (Score: 60)
#  Sent: @niayesh_1beauty (Score: 60)
#  Sent: @lamilashes_official (Score: 60)
#  Sent: @lavie_nail_lounge21 (Score: 60)
#  Sent: @lashes_bysusan (Score: 60)
#  Sent: @lashartisan (Score: 60)
#  Sent: @lashforevercanada_ (Score: 60)
#  Sent: @chang_mescilashes (Score: 60)
#  Sent: @tobeautybar (Score: 60)
#  Sent: @cinnamongirlclinic (Score: 60)
#  Sent: @a1lash.co (Score: 60)
#  Sent: @vietnam_lashes_manufacturer (Score: 60)
#  Sent: @hfxlash (Score: 60)
#  Sent: @levbeautystudio (Score: 60)
#  Sent: @permanentbeautybylili (Score: 60)
#  Sent: @gialilashes (Score: 60)
#  Sent: @formationbeautylounge (Score: 60)
#  Sent: @studio151_beautybar (Score: 60)
#  Sent: @kian_beautyartist (Score: 60)
#  Sent: @allurestudio_sf (Score: 60)
#  Sent: @bratzz.lashesss (Score: 60)
#  Sent: @topgold_lashes (Score: 60)
#  Sent: @unovabeautyclinic (Score: 60)
#  Sent: @eblashsupplies (Score: 60)
#  Sent: @lashworldlondon (Score: 60)
#  Sent: @monika.rzap (Score: 60)
#  Sent: @broadwayflorists (Score: 60)
#  Sent: @gemerry_lashes (Score: 60)
#  Sent: @vogalashes (Score: 60)
#  Sent: @sugarnailsandlashes (Score: 60)
#  Sent: @lashsocialclub (Score: 60)
#  Sent: @summerbbeauty (Score: 60)
#  Sent: @mantrabeautyesthetic (Score: 60)
#  Sent: @lashesmagazine (Score: 60)
#  Sent: @mandalaaestheticspreston (Score: 60)
#  Sent: @karry.bannister69 (Score: 60)
#  Sent: @misshair.bar_extensions (Score: 60)
#  Sent: @taiwanlashess (Score: 60)
#  Sent: @purebarbeaute (Score: 60)
#  Sent: @ilashfairy.official (Score: 60)
#  Sent: @goddesslashacademy (Score: 60)
#  Sent: @vancitybeautylounge (Score: 60)
#  Sent: @glowluxenailsspa (Score: 60)
#  Sent: @tannaz.shahzadi (Score: 60)
#  Failed to send slayedbynevaehh: HTTP 400: {"statusCode":400,"message":"The string supplied did not seem to be a phone number","traceId":"4596b
#  Removed phone number and retrying...
#  Sent: @slayedbynevaehh (Score: 60)
#  Sent: @lashesbysummiya (Score: 60)
#  Failed to send winksbyelise: HTTP 422: {"email":{"message":"The email must be a valid email address.","rule":"email"}}
#  Retrying...
#  Failed to send winksbyelise: HTTP 422: {"email":{"message":"The email must be a valid email address.","rule":"email"}}
#  Sent: @ballylashes_ava3 (Score: 60)
#  Sent: @i.beauty.parlourhfx (Score: 60)
#  Sent: @beautycarebypd (Score: 60)
#  Sent: @academiebeautejt (Score: 60)
#  Sent: @briibeautyservice (Score: 60)
#  Failed to send bonitabeauty.kupang: HTTP 400: {"statusCode":400,"message":"Invalid country calling code","traceId":"046d78f8-0dd6-444a-b786-50443e
#  Retrying...
#  Failed to send bonitabeauty.kupang: HTTP 400: {"statusCode":400,"message":"Invalid country calling code","traceId":"789c87b2-6c2d-4ee2-bbee-b187f6
#  Sent: @lovebeautylashes_laura (Score: 60)
#  Sent: @mxtensions (Score: 60)
#  Sent: @jns.divinelash (Score: 60)
#  Sent: @edenbarbeaute (Score: 60)
#  Sent: @marygol_lashes (Score: 60)
#  Sent: @neighborhood.lash.tech (Score: 60)
#  Sent: @lucybrowsandlashes (Score: 60)
#  Sent: @anielabeauty (Score: 60)
#  Sent: @shimmerlashes (Score: 60)
#  Sent: @fabulashbangkok (Score: 60)
#  Sent: @marjo.moon (Score: 60)
#  Sent: @iris.lashes.bar (Score: 60)
#  Sent: @snob_inc_ (Score: 60)
#  Sent: @lashboxla_uk (Score: 60)
#  Sent: @beautybylianai (Score: 60)
#  Sent: @cubebeautyco (Score: 60)
#  Sent: @zezebeautylounge (Score: 50)
#  Sent: @nellah_flee (Score: 50)
#  Sent: @herroyalpalace (Score: 50)
#  Sent: @junstudios (Score: 50)
#  Sent: @beautique.canada (Score: 50)
#  Sent: @beauty_therapy_ana_russell (Score: 50)
#  Sent: @absolute.beauty.studio (Score: 50)
#  Sent: @guccilash (Score: 50)
#  Sent: @dslashlounge_ (Score: 50)
#  Sent: @gracielashco (Score: 50)
#  Sent: @thebeautedetailist (Score: 50)
#  Sent: @karmcollective (Score: 50)
#  Sent: @marybeautylash_extension (Score: 50)
#  Sent: @artistryfargo (Score: 50)
#  Sent: @ppbeauty.lashes (Score: 50)
#  Sent: @lostartistrylash (Score: 50)
#  Sent: @evbeautycollective (Score: 50)
#  Sent: @beautyavenueco.ca (Score: 50)
#  Sent: @honeytanandwax (Score: 50)
#  Sent: @lovebeautylashes_sara (Score: 50)
#  Sent: @eastvanlashandbrow (Score: 50)
#  Sent: @snow_mintlashes (Score: 50)
#  Sent: @belashed.enhancement (Score: 50)
#  Sent: @swaniyalashes_lorita (Score: 50)
#  Sent: @manufaktura.rzes.i.brwi (Score: 50)
#  Sent: @bealashedd_ (Score: 50)
#  Sent: @momieyelash_ (Score: 50)
#  Sent: @liyah.s.lashes (Score: 50)
#  Sent: @roshanabeautystudio (Score: 50)
#  Sent: @boujee_lashess_ (Score: 50)
#  Sent: @joy_lashesbyserene (Score: 50)
#  Sent: @inlei_boston (Score: 50)
#  Sent: @artistry.mish (Score: 50)
#  Sent: @norisraa_lashes (Score: 50)
#  Sent: @vibeauti (Score: 50)
#  Sent: @curvedtopper (Score: 50)
#  Sent: @touchedbynkem (Score: 50)
#  Sent: @glorious.nailsspa (Score: 50)
#  Sent: @bymollybeauty (Score: 50)
#  Sent: @extendedbyenchanted (Score: 50)
#  Sent: @ontario.region (Score: 50)
#  Sent: @monicajo.lashstudio (Score: 50)
#  Sent: @lashlinellc (Score: 50)
#  Sent: @royal_beauty.club (Score: 50)
#  Sent: @glamit_byvanessa (Score: 50)
#  Sent: @doll_lash_trap (Score: 50)
#  Sent: @richlash_2 (Score: 50)
#  Sent: @ahmed_beautation (Score: 50)
#  Sent: @combinal.canada (Score: 50)
#  Sent: @christinas_lashes (Score: 50)
#  Sent: @lash.getit (Score: 50)
#  Sent: @inlei_canada (Score: 50)
#  Sent: @halifax_nails_and_lashes (Score: 50)
#  Sent: @lashesby.lupe (Score: 50)
#  Sent: @killaspace (Score: 50)
#  Sent: @cateyestrophicbeauty (Score: 50)
#  Sent: @emileana_wls (Score: 50)
#  Sent: @miriamakeupandlashes (Score: 50)
#  Sent: @lady_lash___ (Score: 50)
#  Sent: @diorlashstudios_ (Score: 50)
#  Sent: @cybrlashes (Score: 50)
#  Sent: @roxycils (Score: 50)
#  Sent: @ottawabeautybar.ca (Score: 50)
#  Sent: @primpandpropervancouver (Score: 50)
#  Sent: @lashed.byriri (Score: 50)
#  Sent: @anrolash_lashfactory_cora (Score: 50)
#  Sent: @thelashroomx1 (Score: 50)
#  Sent: @white_beauty.official (Score: 50)
#  Sent: @jbeautycove (Score: 50)
#  Sent: @plumerian_designs (Score: 50)
#  Sent: @selinabeautylounge (Score: 50)
#  Sent: @vi.lashyou (Score: 50)
#  Sent: @xtremelashes.canada (Score: 50)
#  Sent: @lashbytiina (Score: 50)
#  Sent: @lymeelash_manufacturer (Score: 50)
#  Sent: @aestheticbeautystudioyxe (Score: 50)
#  Sent: @glamhouse.vn_ (Score: 50)
#  Sent: @lashes.wholesale_get_samples (Score: 50)
#  Sent: @lash.ily (Score: 50)
#  Sent: @khies_beauty (Score: 50)
#  Sent: @mandibeautylab (Score: 50)
#  Sent: @_havenbeauty_ (Score: 50)
#  Sent: @lashesbymilsz (Score: 50)
#  Sent: @thebeautyroomsoxton (Score: 50)
#  Sent: @reallash_official (Score: 50)
#  Sent: @todaysladyartistry (Score: 50)
# Progress: 200/2140 leads processed (9.3%)
#  Sent: @mp.beautybarr (Score: 50)
#  Sent: @infinai.studios (Score: 50)
#  Sent: @browxlashco (Score: 50)
#  Sent: @nuyubeautestudio (Score: 50)
#  Sent: @chandramarchukbeauty (Score: 50)
#  Sent: @icylashstudio (Score: 50)
#  Sent: @haicherlash (Score: 50)
#  Sent: @artistrybykathy_ (Score: 50)
#  Sent: @linda_lashplus (Score: 50)
#  Sent: @vio_wong_pm (Score: 50)
#  Sent: @boujeebabelashess (Score: 50)
#  Sent: @lashesbyxovia (Score: 50)
#  Sent: @nailedit_oldschoolnails (Score: 50)
#  Sent: @fabutanhushlash.westend (Score: 50)
#  Sent: @lashesbychoi (Score: 50)
#  Failed to send llesthetix: HTTP 400: {"statusCode":400,"message":"The string supplied did not seem to be a phone number","traceId":"856e9
#  Removed phone number and retrying...
#  Sent: @llesthetix (Score: 50)
#  Sent: @lashesbyscali (Score: 50)
#  Sent: @_touchstudio (Score: 50)
#  Sent: @_ac_aesthetics (Score: 50)
#  Sent: @vanislebeautybar (Score: 50)
#  Sent: @gladslashes (Score: 50)
#  Sent: @lashbykoreanjade (Score: 50)
#  Sent: @kikisbeauti (Score: 50)
#  Sent: @beautyspotmtl (Score: 50)
#  Sent: @lashesby.jiya (Score: 50)
#  Sent: @jessica.lashesextension (Score: 50)
#  Sent: @china_eyelash_topstar (Score: 50)
#  Sent: @beautiquecanadaspa (Score: 50)
#  Sent: @bellatudoartandbeauty (Score: 50)
#  Sent: @neenapinkroom (Score: 50)
#  Sent: @thefairylashmotherr (Score: 50)
#  Sent: @embel_lashed (Score: 50)
#  Sent: @lashfx (Score: 50)
#  Sent: @beautyforlashes.ca (Score: 50)
#  Sent: @lashroom_by_des (Score: 50)
#  Sent: @pridebeautylounge (Score: 50)
#  Sent: @thelashdenxo (Score: 50)
#  Sent: @breesbeautyboutique (Score: 50)
#  Sent: @jadevictoriahill (Score: 50)
#  Sent: @yixinbeauty_myla (Score: 50)
#  Sent: @embestudio.ca (Score: 50)
#  Sent: @lashestoronto (Score: 50)
#  Sent: @amz.lashmate (Score: 50)
#  Sent: @joannakellerbeautique (Score: 50)
#  Sent: @yourlilbeauty (Score: 50)
#  Sent: @lashandcouk (Score: 50)
#  Sent: @behie.artistry (Score: 50)
#  Sent: @confidentcomplexionsyyt (Score: 50)
#  Sent: @bloomingbeauty.llc (Score: 50)
#  Sent: @vannitybeautybar (Score: 50)
#  Sent: @religion_beauty_and_tattoo (Score: 50)
#  Sent: @delwyn_industries_tweezers (Score: 50)
#  Sent: @goldwinxbeauty (Score: 50)
#  Exception sending latti.lash: HTTPSConnectionPool(host='rest.gohighlevel.com', port=443): Read timed out. (read timeout=30)
#  Retrying...
#  Failed to send latti.lash: HTTP 520: <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if I
#  Sent: @loftestheticsbysureah (Score: 50)
#  Sent: @chiclashbc (Score: 50)
#  Sent: @london_lash_usca (Score: 50)
#  Sent: @ellanailsandeyelashes (Score: 50)
#  Sent: @lashesbybrooklynlauzon (Score: 50)
#  Sent: @eyedrama (Score: 50)
#  Sent: @hannahsbeauty_bar_calgary (Score: 50)
#  Sent: @luxeliftbyvida (Score: 50)
#  Sent: @kluxequalities (Score: 50)
#  Sent: @waisted.body.beautify.services (Score: 50)
#  Sent: @okt_lashes (Score: 50)
#  Sent: @winkxstudios (Score: 50)
#  Sent: @the_lash_pro_studio (Score: 50)
#  Failed to send prestigious_lashes: HTTP 400: {"statusCode":400,"message":"The string supplied did not seem to be a phone number","traceId":"5c384
#  Removed phone number and retrying...
#  Sent: @prestigious_lashes (Score: 50)
#  Sent: @bestbrowspa (Score: 50)
#  Sent: @dezireartistry (Score: 50)
#  Sent: @trishv.esthetics (Score: 50)
#  Sent: @lashedj (Score: 50)
#  Sent: @mimilashco (Score: 50)
#  Sent: @by.emartistry (Score: 50)
#  Sent: @yxartistry (Score: 50)
#  Sent: @boundbybeauty__ (Score: 50)
#  Sent: @foxxiebeautyroom.bh (Score: 50)
#  Sent: @lashbeauty_abby (Score: 50)
#  Sent: @brenna.newagebeauty (Score: 50)
#  Sent: @eyesbymari (Score: 50)
#  Sent: @anniedzhura (Score: 50)
#  Sent: @aesthetics.by.alyssa (Score: 50)
#  Sent: @palmtree.bb (Score: 50)
#  Sent: @sukislashes (Score: 50)
#  Sent: @hanango.vietnameyelashes (Score: 50)
#  Sent: @adelia.lashlounge__ (Score: 50)
#  Failed to send hollywood_lashes_wakefield: HTTP 400: {"statusCode":400,"message":"Invalid country calling code","traceId":"3a642c59-52f7-4d7a-97ec-9de2de
#  Retrying...
#  Failed to send hollywood_lashes_wakefield: HTTP 400: {"statusCode":400,"message":"Invalid country calling code","traceId":"ec2ce579-0256-47bb-9310-471eb0
#  Sent: @white_beauty_space (Score: 50)
#  Sent: @bratzzlashez (Score: 50)
#  Sent: @alexlashed (Score: 50)
#  Sent: @lash.envy (Score: 50)
#  Sent: @weekend.lashes (Score: 50)
#  Sent: @espacebeautecp (Score: 50)
#  Sent: @designby.chillius (Score: 50)
#  Sent: @beautyonbell_ (Score: 50)
#  Sent: @nats_lashes (Score: 50)
#  Sent: @lavanda.beautystudio (Score: 50)
#  Sent: @beautique.seoul (Score: 50)
#  Sent: @stellalashes (Score: 50)
#  Sent: @styledbykatryna (Score: 50)
#  Sent: @busaybeauty (Score: 50)
#  Sent: @erinicolelash (Score: 50)
#  Sent: @official_abracadabra_closet (Score: 50)
#  Sent: @_._ilash_._ (Score: 50)
#  Sent: @asimplylashco (Score: 50)
#  Sent: @lashedbyalyse (Score: 50)
#  Sent: @lash.brows.art (Score: 50)
#  Sent: @beyondbeautysalon (Score: 50)
#  Sent: @yazstudios_ (Score: 50)
#  Sent: @stylist_bysuzanna (Score: 50)
#  Sent: @onelovelash (Score: 50)
#  Sent: @gltrlash (Score: 50)
#  Sent: @lashes.by.kaylyn (Score: 50)
#  Sent: @lashescouldkill (Score: 50)
#  Sent: @vivian_wax_lash_studio (Score: 50)
#  Sent: @bt.lashbyavocado (Score: 50)
#  Sent: @fantoni.academy (Score: 50)
#  Sent: @lash_room_traralgon (Score: 50)
#  Sent: @maltalashes (Score: 50)
#  Sent: @beautycorner.ca (Score: 50)
#  Sent: @lashedemm (Score: 50)
#  Sent: @poshbeautycopg (Score: 50)
#  Sent: @hannahlashstudio (Score: 50)
#  Sent: @monbeautyco (Score: 50)
#  Sent: @sarahflorko_nails_and_lashes (Score: 50)
#  Sent: @outlashextensionspro (Score: 50)
#  Sent: @taylor_eyez (Score: 50)
#  Sent: @lashesbysals (Score: 50)
#  Sent: @queenby_beauty (Score: 50)
#  Sent: @lashfairy.pro (Score: 50)
#  Sent: @menna_lashess (Score: 50)
#  Sent: @lashlabprofessional (Score: 50)
#  Sent: @charlys_beauties (Score: 50)
#  Sent: @foreveryoungyun (Score: 50)
#  Sent: @ovationnailsnspa (Score: 50)
#  Sent: @goddessstudioca (Score: 50)
#  Sent: @contrastlash (Score: 50)
#  Sent: @lav_lashher (Score: 50)
#  Sent: @theglomeoshop (Score: 50)
#  Sent: @mariame.beauty (Score: 50)
#  Sent: @lashbay.co (Score: 50)
#  Sent: @truly.lashed_ (Score: 50)
#  Sent: @jeyelash___ (Score: 50)
#  Sent: @lashesbyariet (Score: 50)
#  Sent: @aesthetic.temptationss (Score: 50)
#  Sent: @lbvbeauty.__ (Score: 50)
#  Sent: @lethal_lashes_products_academy (Score: 50)
#  Sent: @fantoni.beauty (Score: 50)
#  Sent: @kiaraskylash (Score: 50)
#  Sent: @elusivebeauty.studio (Score: 50)
#  Sent: @beautypalacestudio (Score: 50)
#  Sent: @ky.lashes_xo (Score: 50)
#  Sent: @lash_glamor (Score: 50)
#  Sent: @artstarlashes_factory (Score: 50)
#  Sent: @roseluxe___ (Score: 50)
#  Sent: @houseofbeauty.yeg (Score: 50)
#  Sent: @estheticsbyalanna (Score: 50)
#  Sent: @ottawauniity (Score: 50)
#  Sent: @luna_lashesss (Score: 50)
#  Sent: @katslashes_yyc (Score: 50)
#  Sent: @aziibella.surgical (Score: 50)
#  Sent: @kelly_brow.ca (Score: 50)
#  Sent: @glambarnailandlash (Score: 50)
#  Sent: @brighterbeautycollective (Score: 50)
#  Sent: @lushous.lashes (Score: 50)
#  Sent: @glowbrowlash (Score: 50)
#  Sent: @eyesonyoulashes (Score: 50)
#  Sent: @gabibeauty.gr (Score: 50)
#  Sent: @lashedout_byshan (Score: 50)
#  Sent: @yycaestheticsby.a (Score: 50)
#  Sent: @snezhana_kochura (Score: 50)
#  Sent: @ilashboutique_ottawa (Score: 50)
#  Sent: @eyelashextension_lashvendor (Score: 50)
#  Sent: @emilycolelashes (Score: 50)
#  Sent: @lasheryrhill (Score: 50)
#  Sent: @insightlashartistry (Score: 50)
#  Sent: @lashesbynilo (Score: 50)
#  Sent: @sophiamxbeauty (Score: 50)
#  Sent: @newcomelashes (Score: 50)
#  Sent: @_estheticsbyemily_ (Score: 50)
#  Sent: @lashzby (Score: 50)
#  Sent: @lashes_by_teizha (Score: 50)
#  Sent: @fivestarcorp (Score: 50)
#  Sent: @bardislashbar (Score: 50)
#  Sent: @the17beauty_toronto (Score: 50)
#  Sent: @nailslunajanati (Score: 50)
#  Sent: @lashnthrash (Score: 50)
#  Sent: @galacticwinks (Score: 50)
#  Sent: @kolybellashofficial (Score: 50)
#  Sent: @splash.esthetics (Score: 50)
#  Sent: @iam_antonina.romanenko_ (Score: 50)
#  Sent: @glambysamxo (Score: 50)
#  Sent: @gemini_artistry44 (Score: 50)
#  Sent: @volk_sisters (Score: 50)
#  Sent: @lashed.bylivie (Score: 50)
#  Sent: @lashes.by.nar (Score: 50)
#  Sent: @readysetglow.inc (Score: 50)
#  Sent: @primstudio.yyc (Score: 50)
#  Sent: @meezunderprises (Score: 50)
#  Sent: @exclusivelookesthetics (Score: 50)
# Progress: 400/2140 leads processed (18.7%)
#  Sent: @visit._.netherland (Score: 50)
#  Sent: @artistryaliss (Score: 50)
#  Sent: @nailsbykim.mtl (Score: 50)
#  Sent: @chicnailsandlashes_yeg (Score: 50)
#  Sent: @yeibeautyspa (Score: 50)
#  Sent: @tbs_daria (Score: 50)
#  Sent: @thatbeautycompany_ (Score: 50)
#  Sent: @kozeat.issa_pmu (Score: 50)
#  Sent: @hillarymarialashes (Score: 50)
#  Sent: @melodyco._ (Score: 50)
#  Sent: @beautyxjt (Score: 50)
#  Sent: @megalashstudio_ (Score: 50)
#  Sent: @richeyelashes_shop1 (Score: 50)
#  Sent: @ppbeautyacademy (Score: 50)
#  Sent: @allyxlashes (Score: 50)
#  Sent: @corecreatedent (Score: 50)
#  Sent: @lumierelashbar (Score: 50)

# %%
import csv
from datetime import datetime

# Connect to database
conn = sqlite3.connect('instagram_leads.db')
cursor = conn.cursor()

# Generate timestamp for filename
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"low_scoring_leads_{timestamp}.csv"

try:
    # Query leads with scores under 20
    cursor.execute('''
        SELECT 
            username, email, phone, website_link, follower_count, 
            location, lead_score, date_scraped 
        FROM profiles
        WHERE lead_score < 20
        ORDER BY lead_score DESC, follower_count DESC
    ''')

    leads = cursor.fetchall()
    print(f"Found {len(leads)} low-scoring leads to export.")

    if leads:
        # Write to CSV
        with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            # Write header
            writer.writerow([
                'Username', 'Email', 'Phone', 'Website', 'Follower Count', 
                'Location', 'Lead Score', 'Date Scraped'
            ])
            
            # Write data
            for lead in leads:
                writer.writerow(lead)

        print(f"Successfully exported {len(leads)} leads to {filename}")
    
    # Optional: Also export high-scoring leads that failed to send to GHL
    cursor.execute('''
        SELECT 
            username, email, phone, website_link, follower_count, 
            location, lead_score, date_scraped, error_message 
        FROM profiles
        WHERE lead_score >= 20
        AND (sent_to_crm = 0 OR sent_to_crm IS NULL)
        AND retry_count >= ?
        ORDER BY lead_score DESC
    ''', (MAX_RETRIES,))

    failed_leads = cursor.fetchall()
    
    if failed_leads:
        failed_filename = f"failed_ghl_leads_{timestamp}.csv"
        with open(failed_filename, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            # Write header
            writer.writerow([
                'Username', 'Email', 'Phone', 'Website', 'Follower Count', 
                'Location', 'Lead Score', 'Date Scraped', 'Error Message'
            ])
            
            # Write data
            for lead in failed_leads:
                writer.writerow(lead)
                
        print(f"Also exported {len(failed_leads)} failed high-scoring leads to {failed_filename}")
    
finally:
    conn.close()
    print("Database connection closed.")
